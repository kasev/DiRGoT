# %%
import os
import time
import pandas as pd
import numpy as np
import nltk
import pickle
import json
import sys
sys.setrecursionlimit(10000000)
import re ### to use extended regex library: https://pypi.org/project/regex/
import ast
import csv
from bs4 import BeautifulSoup
import requests
import getpass
from urllib.request import urlopen

# !pip install --ignore-installed sddk ### our own package under construction, always install to have up-to-date version
import sddk
# Out:
# Collecting sddk
#   Downloading https://files.pythonhosted.org/packages/34/30/92ab5e6e5ea4b2b5155fe2da6c95869b5c6a4de4e0c92ee7009cd41cc0cf/sddk-1.6.1-py3-none-any.whl
# Installing collected packages: sddk
# Successfully installed sddk-1.6.1

# %%
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# %%
### authorize google sheets
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
gc = gspread.authorize(GoogleCredentials.get_application_default())
# establish connection with particular sheet by its url:

# RESULTS SPREADSHEET
sh = gc.open_by_url("https://docs.google.com/spreadsheets/d/1v99i42xd9jh0E9O_0-SrCrYE8WI91yQWB03BtJUm97w/edit?usp=sharing")

# %% [markdown]
# # sciencedata.dk configuration
#
# As a data storage, we will use Danish official infrastructure called sciencedata.dk. It is commobly approacheble from any European research institution.
#
# The configuration require having already a proper username and password configurated on the web interface of the platform.

# %%
conf = sddk.configure_session_and_url("dirgot_data", "648597@au.dk")
# Out:
# sciencedata.dk username (format '123456@au.dk'): kase@zcu.cz
# sciencedata.dk password: ··········
# connection with shared folder established with you as its ordinary user
# endpoint variable has been configured to: https://sciencedata.dk/sharingout/648597%40au.dk/dirgot_data/

# %% [markdown]
# # Coptic GoT data

# %%
url = "http://marcion.sourceforge.net/nag-hammadi-library/gospel-of-thomas-en.html#transl"
resp = requests.get(url)

# %%
soup = BeautifulSoup(resp.content, "html.parser")

# %%
coptic_words = []
for td in soup.find_all("td"):
  if "Athena" in str(td):
    td_text = td.get_text()
    if len(td_text) > 0:
      coptic_words.append(td_text)

# %%
coptic_words[:10]
# Out:
# ['ⲛⲁⲉⲓ', 'ⲛⲉ', 'ⲛ-', 'ϣⲁϫⲉ', 'ⲉ[ⲧ]-', '[ϩ]ⲏⲡ+', 'ⲉⲛⲧ-', 'ⲁ-', '(gk) ⲓⲥ', 'ⲉⲧ-']

# %%
set_with_dataframe(sh.add_worksheet("coptic_words", cols=1, rows=1), pd.DataFrame(coptic_words))

# %%
rows = []
for table in soup.find_all("table"):
  table_name = table.find("a").get_text()
  try:
    actual_passage = table.find("big").get_text()
  except:
    actual_passage = ""
  for tr in table.find_all("tr"):
    row = []
    row.extend([table_name, actual_passage])
    for td in tr.find_all("td"):
      row.append(td.get_text())
    rows.append(row)

# %%
got_coptic_raw = pd.DataFrame(rows[1:])
got_coptic_raw.drop([5, 6, 7], axis=1, inplace=True)
got_coptic_raw.dropna(thresh=4, inplace=True)
got_coptic_raw.columns = ["line", "context", "coptic", "translation", "code"]
got_coptic_raw.head(40)
# Out:
#                line  ...          code
# 1   (32/10)-(32/12)  ...         3-52.
# 2   (32/10)-(32/12)  ...        3-306.
# 3   (32/10)-(32/12)  ...         3-80.
# 4   (32/10)-(32/12)  ...        2-3189
# 5   (32/10)-(32/12)  ...        3-355.
# 6   (32/10)-(32/12)  ...          1-37
# 7   (32/10)-(32/12)  ...        3-360.
# 8   (32/10)-(32/12)  ...       3-200a.
# 9   (32/10)-(32/12)  ...      4-ihsous
# 10  (32/10)-(32/12)  ...        3-355.
# 11  (32/10)-(32/12)  ...          1-38
# 12  (32/10)-(32/12)  ...          1-39
# 13  (32/10)-(32/12)  ...         3-35.
# 14  (32/10)-(32/12)  ...         1-536
# 15  (32/10)-(32/12)  ...       3-199a.
# 16  (32/10)-(32/12)  ...          1-40
# 17  (32/10)-(32/12)  ...         3-35.
# 18  (32/10)-(32/12)  ...        1-1234
# 19  (32/10)-(32/12)  ...     4-didumos
# 20  (32/10)-(32/12)  ...      4-ioudas
# 21  (32/10)-(32/12)  ...       4-qwmas
# 25  (32/12)-(32/14)  ...         1-536
# 26  (32/12)-(32/14)  ...          1-42
# 27  (32/12)-(32/14)  ...         3-35.
# 28  (32/12)-(32/14)  ...         1-365
# 29  (32/12)-(32/14)  ...        3-367.
# 30  (32/12)-(32/14)  ...       3-200a.
# 31  (32/12)-(32/14)  ...          1-41
# 32  (32/12)-(32/14)  ...        3-261.
# 33  (32/12)-(32/14)  ...         3-80.
# 34  (32/12)-(32/14)  ...    4-ermhneia
# 35  (32/12)-(32/14)  ...        3-262.
# 36  (32/12)-(32/14)  ...         3-52.
# 37  (32/12)-(32/14)  ...        2-3189
# 38  (32/12)-(32/14)  ...       3-199a.
# 39  (32/12)-(32/14)  ...         1-131
# 40  (32/12)-(32/14)  ...        2-2305
# 41  (32/12)-(32/14)  ...  3-396. Negat
# 42  (32/12)-(32/14)  ...        3-262.
# 43  (32/12)-(32/14)  ...         3-80.
#
# [40 rows x 5 columns]

# %%
### look for rows which are probably not Jesus' sayings
def context_identifier(row):
  trans = row["translation"]
  for string in ["say", "Iesus"]:
    if string in trans:
      return "n"
    else:
      return "y"

got_coptic_raw["saying?"] = got_coptic_raw.apply(lambda row: context_identifier(row), axis=1)

# %%
### just for checking
got_coptic_raw.head(5)

# %%
len(got_coptic_raw["code"].unique().tolist())
# Out:
# 621

# %%
len(got_coptic_raw["coptic"].unique().tolist())
# Out:
# 950

# %%
set_with_dataframe(sh.add_worksheet("got_coptic_raw", cols=1, rows=1), pd.DataFrame(got_coptic_raw))

# %% [markdown]
# # Start with manually coded data

# %%
### we have manually coded the data in googlesheets
### see the variable "saying?"
### "y" - words asigned to Jesus
### "n" - rest of the text, including direct speeches pronounced by others

got_coptic_coded = get_as_dataframe(sh.worksheet("got_coptic_coded"))
got_coptic_coded
# Out:
#                  line  ... saying?
# 0     (32/10)-(32/12)  ...       n
# 1     (32/10)-(32/12)  ...       n
# 2     (32/10)-(32/12)  ...       n
# 3     (32/10)-(32/12)  ...       n
# 4     (32/10)-(32/12)  ...       n
# ...               ...  ...     ...
# 5957  (51/27)-(51/28)  ...       n
# 5958  (51/27)-(51/28)  ...       n
# 5959  (51/27)-(51/28)  ...       n
# 5960  (51/27)-(51/28)  ...       n
# 5961  (51/27)-(51/28)  ...       n
#
# [5962 rows x 6 columns]

# %%
### write coded data to sciencedata.dk for backup
sddk.write_file("got_coptic_coded.json", got_coptic_coded, conf)
# Out:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/sharingout/648597%40au.dk/dirgot_data/got_coptic_coded.json"

# %%
len(got_coptic_coded)
# Out:
# 5962

# %%
got_coptic_sayings = got_coptic_coded[got_coptic_coded["saying?"]=="y"]
len(got_coptic_sayings)
# Out:
# 4896

# %%
len(got_coptic_sayings["coptic"].unique().tolist())
# Out:
# 882

# %%
len(got_coptic_sayings["code"].unique().tolist())
# Out:
# 581

# %%
codes_and_terms = []
codes_unique = got_coptic_sayings["code"].unique().tolist()
for code in codes_unique:
  if "." in str(code):
    dot = True
  else:
    dot = False
  df_temp = got_coptic_sayings[got_coptic_sayings["code"]==code]
  code_count = len(df_temp)
  terms = df_temp["coptic"].unique().tolist()
  translations = df_temp["translation"].unique().tolist()
  codes_and_terms.append([code, code_count, terms, translations, dot])

# %%
codes_and_terms = sorted(codes_and_terms, key=lambda x: x[1], reverse=True)

# %%
codes_and_terms_df = pd.DataFrame(codes_and_terms)
codes_and_terms_df.columns = ["code", "count", "coptic", "translation", "dotted"]
codes_and_terms_df.head(10)
# Out:
#       code  count  ...                                        translation dotted
# 0    3-80.    385  ...       [(def art f s), (def art m s), (def art pl)]   True
# 1    3-35.    347  ...  [(suff pron 3rd s m), (suff pron 3rd s f), (su...   True
# 2   3-262.    326  ...  [(gen), (ind obj of vb), (loc) in, (adj), (loc...   True
# 3  3-199a.    279  ...  [(fut 3rd s m), (fut 3rd pl), (fut 2st pl), (p...   True
# 4   3-188.    163  ...  [(circ 3rd s m), (pres 3rd s m), (pres 3st pl)...   True
# 5    3-50.    125  ...  [(m) your (pl), (pl) his, (s m) your (m), (f) ...   True
# 6   3-261.    116  ...          [to, for, (dat), against, about, towards]   True
# 7    1-536    116  ...                                              [and]  False
# 8    3-85.    110  ...                    [(indef art s), (indef art pl)]   True
# 9     1-23     78  ...               [act, become, befall, make, do, do!]  False
#
# [10 rows x 5 columns]

# %%
set_with_dataframe(sh.add_worksheet("codes_and_terms", cols=1, rows=1), codes_and_terms_df)

# %%
### write this dictionary to sciencedata.dk for backup
sddk.write_file("got_codes_and_terms.json", codes_and_terms_df, conf)
# Out:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/sharingout/648597%40au.dk/dirgot_data/got_codes_and_terms.json"

# %%
### let's take a look at terms without dots

codes_and_terms_filtered = codes_and_terms_df[codes_and_terms_df["dotted"]==False]
codes_and_terms_filtered
# Out:
#        code  count  ...                           translation dotted
# 7     1-536    116  ...                                 [and]  False
# 9      1-23     78  ...  [act, become, befall, make, do, do!]  False
# 11    1-365     68  ...       [:, that, because, if, whether]  False
# 16    2-174     47  ...                 [outward, forth, out]  False
# 17     1-13     41  ...                   [be, exist, become]  False
# ..      ...    ...  ...                                   ...    ...
# 576  1-1388      1  ...                              [plough]  False
# 577  4-arxw      1  ...                               [begin]  False
# 578  1-2521      1  ...                           [roll back]  False
# 579   1-531      1  ...                           [be spread]  False
# 580     NaN      0  ...                                    []  False
#
# [522 rows x 5 columns]

# %%
set_with_dataframe(sh.add_worksheet("codes_and_terms_filtered", cols=1, rows=1), codes_and_terms_filtered)

# %%
### write coded data to sciencedata.dk for backup
sddk.write_file("got_codes_and_terms.json", codes_and_terms_df, conf)

# %% [markdown]
# # Rearranging data structure

# %%
def check_dot(row):
  try:
    if "." in row["code"]:
      return True
    else:
      return False
  except:
    return True
got_coptic_sayings["dotted"] = got_coptic_sayings.apply(lambda row: check_dot(row), axis=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
got_coptic_sayings = got_coptic_sayings[got_coptic_sayings["dotted"]==False]
got_coptic_sayings.drop(["saying?", "dotted"], axis=1, inplace=True)
got_coptic_sayings.head(10)
# Out:
#                line  ...        code
# 27  (32/12)-(32/14)  ...        1-41
# 30  (32/12)-(32/14)  ...  4-ermhneia
# 35  (32/12)-(32/14)  ...       1-131
# 36  (32/12)-(32/14)  ...      2-2305
# 40  (32/12)-(32/14)  ...       2-747
# 45  (32/14)-(32/16)  ...        1-43
# 46  (32/14)-(32/16)  ...      1-1234
# 48  (32/14)-(32/16)  ...        1-46
# 50  (32/14)-(32/16)  ...        1-46
# 52  (32/14)-(32/16)  ...        1-47
#
# [10 rows x 5 columns]

# %%
got_lines_data = [] 
for line in got_coptic_sayings["line"].unique().tolist():
  line_df = got_coptic_sayings[got_coptic_sayings["line"]==line] 
  line_codes = line_df["code"].tolist()
  line_eng_terms = line_df["translation"].tolist()
  line_eng_context = line_df["context"].tolist()[0]
  got_lines_data.append([line, line_codes, line_eng_terms, line_eng_context])
got_lines_data[:5]
# Out:
# [['(32/12)-(32/14)',
#   ['1-41', '4-ermhneia', '1-131', '2-2305', '2-747'],
#   ['find', 'explanation', 'take', 'taste', 'death'],
#   '(1) And he said: "Whoever finds the meaning of these words will not taste death."'],
#  ['(32/14)-(32/16)',
#   ['1-43',
#    '1-1234',
#    '1-46',
#    '1-46',
#    '1-47',
#    '1-536',
#    '4-otan',
#    '1-674',
#    '1-47'],
#   ['cease, stop',
#    '(nom)',
#    'seek',
#    'ask',
#    'find',
#    'and',
#    'when',
#    'if, when',
#    'find'],
#   '(2) Jesus says: "The one who seeks should not cease seeking until he finds. And when he finds,'],
#  ['(32/16)-(32/19)',
#   ['1-45',
#    '1-536',
#    '1-674',
#    '1-45',
#    '1-23',
#    '1-44',
#    '1-536',
#    '1-23',
#    '1-18',
#    '1-48'],
#   ['be disturbed, troubled',
#    'and',
#    'if, when',
#    'be disturbed, troubled',
#    'act',
#    'amazement',
#    'and',
#    'act',
#    'king',
#    'all'],
#   'he will be dismayed. And when he is dismayed, he will be astonished. And he will be king over the All."'],
#  ['(32/19)-(32/23)',
#   ['1-674',
#    '1-1234',
#    '1-49',
#    '1-365',
#    '2-407',
#    '1-18',
#    '1-50',
#    '1-691',
#    '1-51',
#    '1-23',
#    '2-3083',
#    '1-50'],
#   ['if, when',
#    '(nom)',
#    'draw',
#    ':',
#    'behold',
#    'king',
#    'heaven',
#    'then',
#    'bird',
#    'become, befall',
#    'earliest, first',
#    'heaven'],
#   '(03) Jesus says: "If those who lead you say to you: ‘Look, the kingdom is in the sky!’ then the birds of the sky will precede you.'],
#  ['(32/23)-(32/24)',
#   ['1-674', '1-365', '4-qalassa', '1-691', '1-52', '1-23', '2-3083'],
#   ['if, when',
#    ':',
#    'sea',
#    'then',
#    'fish',
#    'become, befall',
#    'earliest, first'],
#   'If they say to you: ‘It is in the sea,’ then the fishes will precede you.']]

# %%
got_lines_data_df = pd.DataFrame(got_lines_data)
got_lines_data_df.columns = ["line", "codes", "eng_terms", "eng_sentence"]
got_lines_data_df.head(10)
# Out:
#               line  ...                                       eng_sentence
# 0  (32/12)-(32/14)  ...  (1) And he said: "Whoever finds the meaning of...
# 1  (32/14)-(32/16)  ...  (2) Jesus says: "The one who seeks should not ...
# 2  (32/16)-(32/19)  ...  he will be dismayed. And when he is dismayed, ...
# 3  (32/19)-(32/23)  ...  (03) Jesus says: "If those who lead you say to...
# 4  (32/23)-(32/24)  ...  If they say to you: ‘It is in the sea,’ then t...
# 5  (32/25)-(32/26)  ...  Rather, the kingdom is inside of you, and outs...
# 6   (32/26)-(33/1)  ...  "When you come to know yourselves, then you wi...
# 7    (33/1)-(33/2)  ...  and you will realize that you are the children...
# 8    (33/2)-(33/5)  ...  But if you do not come to know yourselves, the...
# 9    (33/5)-(33/6)  ...       (04) Jesus says: "The person old in his days
#
# [10 rows x 4 columns]

# %%
### write out for subsequent analyses
sddk.write_file("got_lines_data.json", got_lines_data_df, conf)
# Out:
# Your <class 'pandas.core.frame.DataFrame'> object has been succefully written as "https://sciencedata.dk/sharingout/648597%40au.dk/dirgot_data/got_lines_data.json"

# %% [markdown]
# # Overview

# %%
got_lines_data = sddk.read_file("got_lines_data.json", "df", conf)

# %%
len(got_lines_data)
# Out:
# 273

# %%
one_list = []
for line in got_lines_data["codes"].tolist():
  one_list.extend(line)
# Out:
# ['1-41',
#  '4-ermhneia',
#  '1-131',
#  '2-2305',
#  '2-747',
#  '1-43',
#  '1-1234',
#  '1-46',
#  '1-46',
#  '1-47',
#  '1-536',
#  '4-otan',
#  '1-674',
#  '1-47',
#  '1-45',
#  '1-536',
#  '1-674',
#  '1-45',
#  '1-23',
#  '1-44',
#  '1-536',
#  '1-23',
#  '1-18',
#  '1-48',
#  '1-674',
#  '1-1234',
#  '1-49',
#  '1-365',
#  '2-407',
#  '1-18',
#  '1-50',
#  '1-691',
#  '1-51',
#  '1-23',
#  '2-3083',
#  '1-50',
#  '1-674',
#  '1-365',
#  '4-qalassa',
#  '1-691',
#  '1-52',
#  '1-23',
#  '2-3083',
#  '4-alla',
#  '1-18',
#  '1-53',
#  '1-536',
#  '2-163',
#  '4-otan',
#  '1-674',
#  '1-55',
#  '4-tote',
#  '1-55',
#  '1-536',
#  '1-56',
#  '1-365',
#  '1-20',
#  '1-57',
#  '1-38',
#  '2-3050',
#  '4-de',
#  '1-55',
#  '1-691',
#  '1-13',
#  '2-3379',
#  '1-536',
#  '2-3379',
#  '1-59',
#  '1-1234',
#  '1-21',
#  '1-63',
#  '1-64',
#  '1-60',
#  '1-61',
#  '1-20',
#  '1-62',
#  '1-65',
#  '1-64',
#  '4-topos',
#  '2-2796',
#  '1-536',
#  '1-38',
#  '1-365',
#  '1-66',
#  '2-3083',
#  '1-23',
#  '1-67',
#  '1-536',
#  '1-13',
#  '1-68',
#  '1-69',
#  '1-55',
#  '1-70',
#  '1-71',
#  '2-174',
#  '1-536',
#  '1-37',
#  '1-27',
#  '2-174',
#  '1-72',
#  '4-gar',
#  '1-37',
#  '1-73',
#  '2-174',
#  '1-39',
#  '1-77',
#  '1-536',
#  '1-78',
#  '1-23',
#  '1-365',
#  '1-27',
#  '1-48',
#  '2-174',
#  '1-70',
#  '2-174',
#  '1-50',
#  '1-72',
#  '4-gar',
#  '1-37',
#  '1-73',
#  '2-174',
#  '1-536',
#  '1-72',
#  '1-79',
#  '1-80',
#  '2-2693',
#  '1-27',
#  '4-makarios',
#  '1-81',
#  '1-21',
#  '1-76',
#  '1-536',
#  '1-81',
#  '1-13',
#  '1-21',
#  '1-536',
#  '1-82',
#  '1-1234',
#  '1-21',
#  '1-81',
#  '1-76',
#  '1-536',
#  '1-81',
#  '1-13',
#  '1-21',
#  '1-21',
#  '1-83',
#  '1-84',
#  '1-21',
#  '1-19',
#  '1-85',
#  '1-86',
#  '4-qalassa',
#  '1-49',
#  '2-7937',
#  '4-qalassa',
#  '1-87',
#  '1-52',
#  '1-61',
#  '2-3477',
#  '1-41',
#  '1-88',
#  '1-52',
#  '1-109',
#  '1-1234',
#  '1-84',
#  '1-21',
#  '1-19',
#  '1-85',
#  '1-61',
#  '1-48',
#  '1-52',
#  '2-174',
#  '1-111',
#  '4-qalassa',
#  '1-89',
#  '1-88',
#  '1-52',
#  '4-xwris',
#  '2-3592',
#  '1-33',
#  '1-29',
#  '1-149',
#  '1-149',
#  '2-407',
#  '1-5',
#  '2-174',
#  '1-1234',
#  '1-91',
#  '1-87',
#  '2-2321',
#  '1-85',
#  '1-100',
#  '4-men',
#  '1-41',
#  '1-101',
#  '1-5',
#  '1-1234',
#  '1-51',
#  '1-536',
#  '1-883',
#  '2-429',
#  '1-41',
#  '4-petra',
#  '1-536',
#  '1-105',
#  '1-110',
#  '2-272',
#  '1-108',
#  '1-536',
#  '1-113',
#  '1-114',
#  '2-3530',
#  '1-50',
#  '1-536',
#  '2-429',
#  '1-41',
#  '1-104',
#  '1-106',
#  '1-112',
#  '1-536',
#  '1-107',
#  '1-76',
#  '1-536',
#  '2-429',
#  '1-41',
#  '1-108',
#  '1-109',
#  '1-536',
#  '1-2',
#  '4-karpos',
#  '2-3530',
#  '1-50',
#  '1-109',
#  '1-5',
#  '2-8734',
#  '1-1495',
#  '1-536',
#  '1-1848',
#  '1-2473',
#  '1-1495',
#  '1-85',
#  '1-115',
#  '4-kosmos',
#  '1-536',
#  '2-407',
#  '1-116',
#  '1-117',
#  '1-50',
#  '1-23',
#  '4-paragw',
#  '1-536',
#  '1-50',
#  '1-23',
#  '4-paragw',
#  '1-536',
#  '1-118',
#  '1-38',
#  '1-536',
#  '1-38',
#  '1-118',
#  '1-64',
#  '1-76',
#  '1-118',
#  '1-23',
#  '1-38',
#  '4-otan',
#  '1-674',
#  '1-13',
#  '1-1',
#  '1-23',
#  '1-64',
#  '1-23',
#  '1-68',
#  '1-23',
#  '1-119',
#  '4-otan',
#  '4-de',
#  '1-674',
#  '1-13',
#  '1-119',
#  '1-23',
#  '1-332',
#  '1-5',
#  '2-8722',
#  '1-123',
#  '4-iakwbos',
#  '4-dikaios',
#  '1-50',
#  '1-108',
#  '1-13',
#  '1-83',
#  '1-39',
#  '1-365',
#  '1-125',
#  '1-1182',
#  '2-2110',
#  '4-epei',
#  '1-127',
#  '1-128',
#  '2-3472',
#  '4-phgh',
#  '1-129',
#  '1-130',
#  '1-674',
#  '1-23',
#  '4-nhsteuw',
#  '1-6',
#  '1-137',
#  '1-536',
#  '1-674',
#  '1-75',
#  '1-23',
#  '4-2 katakrinw',
#  '1-536',
#  '1-674',
#  '1-2',
#  '4-elehmosunh',
#  '1-23',
#  '4-kakos',
#  '4-pneuma',
#  '1-536',
#  '1-674',
#  '1-123',
#  '2-3485',
#  '1-108',
#  '1-1183',
#  '1-536',
#  '1-138',
#  '4-xwra',
#  '1-674',
#  '1-23',
#  '4-2 paradexomai',
#  '1-139',
#  '1-76',
#  '1-140',
#  '1-23',
#  '4-qerapeuw',
#  '1-123',
#  '4-gar',
#  '2-3474',
#  '1-126',
#  '1-141',
#  '4-alla',
#  '2-1130',
#  '2-3472',
#  '1-126',
#  '1-141',
#  '4-otan',
#  '1-674',
#  '1-30',
#  '1-6',
#  '2-3472',
#  '1-143',
#  '1-142',
#  '1-71',
#  '1-144',
#  '2-8758',
#  '1-57',
#  '4-taxa',
#  '1-145',
#  '1-1234',
#  '1-21',
#  '1-365',
#  '1-5',
#  '1-85',
#  '4-eirhnh',
#  '4-kosmos',
#  '1-536',
#  '1-55',
#  '1-365',
#  '1-5',
#  '1-85',
#  '2-1432',
#  '1-108',
#  '1-115',
#  '1-147',
#  '4-polemos',
#  '1-1664',
#  '4-gar',
#  '1-13',
#  '1-32',
#  '1-132',
#  '1-13',
#  '1-119',
#  '1-536',
#  '1-119',
#  '1-132',
#  '1-57',
#  '1-20',
#  '1-536',
#  '1-20',
#  '1-57',
#  '1-536',
#  '1-148',
#  '2-1616',
#  '1-23',
#  '4-monaxos',
#  '1-2',
#  '1-28',
#  '1-30',
#  '1-536',
#  '1-29',
#  '1-149',
#  '1-536',
#  '1-150',
#  '1-2570',
#  '1-536',
#  '1-5',
#  '2-3530',
#  '1-19',
#  '1-21',
#  '1-27',
#  '4-gar',
#  '2-174',
#  '4-arxh',
#  '1-2384',
#  '1-46',
#  '1-67',
#  '1-365',
#  '1-332',
#  '4-arxh',
#  '2-8722',
#  '1-67',
#  '1-13',
#  '2-8722',
#  '4-makarios',
#  '1-148',
#  '2-1616',
#  '4-arxh',
#  '1-536',
#  '1-55',
#  '1-67',
#  '1-536',
#  '1-131',
#  '2-2305',
#  '2-747',
#  '4-makarios',
#  '1-13',
#  '1-227',
#  '1-13',
#  '1-674',
#  '1-13',
#  '4-maqhths',
#  '1-149',
#  '1-135',
#  '1-23',
#  '4-diakonew',
#  '1-33',
#  '4-gar',
#  '2-8722',
#  '1-1664',
#  '1-325',
#  '4-paradeisos',
#  '1-213',
#  '1-940',
#  '1-939',
#  '1-536',
#  '1-327',
#  '1-41',
#  '2-174',
#  '1-55',
#  '1-131',
#  '2-2305',
#  '2-747',
#  '1-83',
#  '1-575',
#  '1-1916',
#  '1-1378',
#  '4-para',
#  '1-112',
#  '1-48',
#  '4-otan',
#  '4-de',
#  '1-674',
#  '1-41',
#  '1-108',
#  '1-23',
#  '1-120',
#  '1-113',
#  '2-174',
#  '1-88',
#  '1-1618',
#  '1-13',
#  '4-skeph',
#  '1-51',
#  '1-50',
#  '1-125',
#  '1-20',
#  '1-62',
#  '1-2523',
#  '1-152',
#  '4-otan',
#  '1-674',
#  '1-5',
#  '1-1234',
#  '1-17',
#  '1-152',
#  '1-365',
#  '1-139',
#  '1-152',
#  '2-174',
#  '2-4255',
#  '1-70',
#  '2-174',
#  '1-139',
#  '2-174',
#  '1-2',
#  '1-152',
#  '4-dia touto',
#  '1-365',
#  '1-674',
#  '1-56',
#  '1-1234',
#  '1-17',
#  '1-32',
#  '1-365',
#  '2-1130',
#  '1-1234',
#  '1-154',
#  '1-155',
#  '1-5',
#  '1-139',
#  '1-156',
#  '2-3485',
#  '1-32',
#  '1-18',
#  '1-134',
#  '4-skeuos',
#  '4-de',
#  '1-155',
#  '1-227',
#  '4-kosmos',
#  '1-157',
#  '1-158',
#  '1-88',
#  '4-dunamis',
#  '4-ina',
#  '1-365',
#  '4-lhsths',
#  '1-41',
#  '1-101',
#  '1-5',
#  '4-epei',
#  '4-xreia',
#  '1-223',
#  '2-174',
#  '1-41',
#  '1-13',
#  '1-159',
#  '1-1234',
#  '1-21',
#  '4-episthmwn',
#  '4-karpos',
#  '1-160',
#  '1-5',
#  '1-161',
#  '2-2872',
#  '1-150',
#  '1-162',
#  '1-33',
#  '1-29',
#  '1-149',
#  '1-149',
#  '1-61',
#  '1-131',
#  '1-163',
#  '1-83',
#  '1-123',
#  '2-3485',
#  '1-18',
#  '1-2',
#  '1-167',
#  '1-135',
#  '1-384',
#  '2-174',
#  '1-1234',
#  '1-872',
#  '1-135',
#  '1-904',
#  '4-otan',
#  '1-674',
#  '1-23',
#  '1-119',
#  '1-68',
#  '1-536',
#  '1-674',
#  '1-23',
#  '1-1364',
#  '1-53',
#  '2-3279',
#  '1-1364',
#  '2-163',
#  '1-536',
#  '1-1364',
#  '2-163',
#  '2-3279',
#  '1-1364',
#  '1-53',
#  '1-536',
#  '1-1364',
#  '2-1388',
#  '2-3279',
#  '1-1364',
#  '1-212',
#  '1-536',
#  '4-ina',
#  '1-23',
#  '1-166',
#  '1-143',
#  '1-68',
#  '1-69',
#  '1-2384',
#  '1-166',
#  '1-23',
#  '1-166',
#  '1-143',
#  '1-23',
#  '1-143',
#  '4-otan',
#  '1-674',
#  '1-23',
#  '1-28',
#  '1-332',
#  '1-28',
#  '1-536',
#  '1-150',
#  '1-332',
#  '1-150',
#  '1-536',
#  '1-306',
#  '1-332',
#  '1-306',
#  '4-eikwn',
#  '1-332',
#  '4-eikwn',
#  '4-tote',
#  '1-123',
#  '2-3485',
#  '1-18',
#  '1-89',
#  '1-68',
#  '2-3472',
#  '1-536',
#  '1-119',
#  '2-3472',
#  '1-536',
#  '1-148',
#  '2-1616',
#  '1-23',
#  '1-68',
#  '1-69',
#  '1-33',
#  '1-29',
#  '1-149',
#  '1-1',
#  '1-13',
#  '1-53',
#  '1-21',
#  '1-1',
#  '1-536',
#  '1-23',
#  '1-1',
#  '4-kosmos',
#  '1-48',
#  '1-23',
#  '1-1',
#  '1-168',
#  '1-169',
#  '1-174',
#  '2-3279',
#  '4-cuxh',
#  '1-23',
#  '4-threw',
#  '2-3279',
#  '1-424',
#  '1-28',
#  '1-172',
#  '1-28',
#  '1-174',
#  '1-30',
#  '1-1369',
#  '4-de',
#  '1-28',
#  '1-30',
#  '4-otan',
#  '1-674',
#  '1-85',
#  '1-1369',
#  '2-3472',
#  '1-28',
#  '4-tote',
#  '1-30',
#  '2-174',
#  '1-85',
#  '1-172',
#  '2-3472',
#  '1-28',
#  '1-174',
#  '1-914',
#  '1-23',
#  '4-nhsteuw',
#  '4-kosmos',
#  '1-41',
#  '1-18',
#  '1-914',
#  '1-23',
#  '4-sabbaton',
#  '4-sabbaton',
#  '1-30',
#  '1-57',
#  '1-148',
#  '2-1616',
#  '1-159',
#  '4-kosmos',
#  '1-536',
#  '1-73',
#  '2-174',
#  '4-sarj',
#  '1-41',
#  '1-48',
#  '1-128',
#  '1-41',
#  '1-72',
#  '1-175',
#  '1-536',
#  '4-cuxh',
#  '1-2',
#  '1-176',
#  '1-20',
#  '1-21',
#  '1-365',
#  '1-177',
#  '1-19',
#  '1-536',
#  '1-30',
#  '2-174',
#  '1-365',
#  '1-5',
#  '4-kosmos',
#  '2-3151',
#  '1-46',
#  '1-450',
#  '1-5',
#  '2-3472',
#  '4-kosmos',
#  '2-3151',
#  '4-plhn',
#  '2-2598',
#  '1-128',
#  '4-otan',
#  '1-674',
#  '1-179',
#  '1-180',
#  '4-tote',
#  '1-23',
#  '4-metanoew',
#  '1-681',
#  '4-sarj',
#  '1-13',
#  '4-pneuma',
#  '1-44',
#  '1-681',
#  '4-pneuma',
#  '4-de',
#  '4-swma',
#  '1-44',
#  '1-44',
#  '4-alla',
#  '1-23',
#  '1-44',
#  '1-365',
#  '4-pws',
#  '1-88',
#  '2-1567',
#  '1-34',
#  '2-3379',
#  '1-332',
#  '1-33',
#  '1-132',
#  '1-31',
#  '2-8722',
#  '1-31',
#  '1-332',
#  '1-33',
#  '1-119',
#  '4-h',
#  '1-68',
#  '1-13',
#  '4-profhths',
#  '1-9',
#  '1-181',
#  '1-182',
#  '1-23',
#  '4-qerapeuw',
#  '1-55',
#  '4-polis',
#  '1-872',
#  '1-183',
#  '1-16',
#  '1-184',
#  '1-151',
#  '1-41',
#  '4-oude',
#  '1-10',
#  '1-37',
#  '1-149',
#  '1-29',
#  '1-103',
#  '1-29',
#  '1-1673',
#  '1-186',
#  '1-188',
#  '1-72',
#  '4-gar',
#  '1-117',
#  '1-189',
#  '1-139',
#  '1-1162',
#  '4-oude',
#  '1-139',
#  '1-332',
#  '1-37',
#  '4-alla',
#  '1-139',
#  '4-luxnia',
#  '1-2384',
#  '1-1728',
#  '1-1183',
#  '1-123',
#  '2-3485',
#  '1-536',
#  '2-1130',
#  '2-174',
#  '1-30',
#  '1-1',
#  '1-177',
#  '1-674',
#  '1-49',
#  '1-177',
#  '1-41',
#  '1-119',
#  '2-272',
#  '1-190',
#  '1-151',
#  '1-68',
#  '1-123',
#  '2-3485',
#  '1-32',
#  '2-3898',
#  '1-131',
#  '1-191',
#  '4-eimhti',
#  '1-157',
#  '1-150',
#  '4-tote',
#  '1-192',
#  '2-174',
#  '1-32',
#  '1-134',
#  '2-1639',
#  '1-2315',
#  '1-707',
#  '1-536',
#  '1-707',
#  '1-2315',
#  '1-365',
#  '1-2',
#  '4-otan',
#  '1-674',
#  '1-153',
#  '2-3037',
#  '1-536',
#  '1-134',
#  '1-193',
#  '1-139',
#  '1-111',
#  '1-306',
#  '2-3279',
#  '1-61',
#  '1-20',
#  '1-62',
#  '1-2350',
#  '4-tote',
#  '1-30',
#  '1-20',
#  '1-38',
#  '1-536',
#  '1-23',
#  '1-195',
#  '1-66',
#  '1-196',
#  '1-23',
#  '4-epiqumew',
#  '1-149',
#  '1-536',
#  '1-103',
#  '1-68',
#  '1-149',
#  '1-64',
#  '1-13',
#  '1-46',
#  '1-41',
#  '4-farisaios',
#  '4-grammateus',
#  '1-131',
#  '1-197',
#  '4-gnwsis',
#  '1-37',
#  '4-oude',
#  '1-123',
#  '2-3485',
#  '1-536',
#  '1-74',
#  '1-123',
#  '2-3485',
#  '1-139',
#  '4-de',
#  '1-13',
#  '4-fronimos',
#  '2-3279',
#  '1-312',
#  '1-536',
#  '4-akeraios',
#  '2-3279',
#  '1-2610',
#  '1-406',
#  '1-198',
#  '1-337',
#  '1-1364',
#  '2-163',
#  '1-57',
#  '1-536',
#  '1-184',
#  '1-200',
#  '1-110',
#  '1-199',
#  '4-ihsous',
#  '1-365',
#  '1-33',
#  '1-150',
#  '1-2',
#  '1-536',
#  '1-103',
#  '1-62',
#  '1-33',
#  '1-134',
#  '1-13',
#  '1-23',
#  '4-paragw',
#  '1-56',
#  '1-365',
#  '1-1182',
#  '4-alla',
#  '1-13',
#  '2-3279',
#  '4-ioudaios',
#  '1-365',
#  '1-169',
#  '1-325',
#  '2-919',
#  '4-karpos',
#  '1-536',
#  '1-169',
#  '4-karpos',
#  '2-919',
#  '1-325',
#  '1-39',
#  '1-1705',
#  '1-57',
#  '1-139',
#  '2-174',
#  '1-536',
#  '1-39',
#  '1-1705',
#  '1-20',
#  '1-139',
#  '2-174',
#  '1-39',
#  '1-1705',
#  '4-de',
#  '4-pneuma',
#  '1-381',
#  '1-139',
#  '2-174',
#  '4-oude',
#  '1-108',
#  '4-oude',
#  '1-50',
#  '1-1031',
#  '1-198',
#  '2-3472',
#  '1-104',
#  '4-oude',
#  '1-883',
#  '1-726',
#  '2-3472',
#  '1-1461',
#  '1-2569',
#  '1-2',
#  ...]

# %%
stopwords_coptic = ["1-536", "1-365", "2-174", "1-674", "2-8722", "1-1234", "2-3472", "1-139", "4-de", "4-otan", "2-3485", "4-gar", "4-alla", "4-ina", "4-oude", "2-2335"]

# %%
len(one_list)
# Out:
# 2203

# %%
len([code for code in one_list if code not in stopwords_coptic])
# Out:
# 1751

# %%
np.round((1654 /  1751) * 100, 4)
# Out:
# 94.4603

# %%
1751 / 273
# Out:
# 6.413919413919414
